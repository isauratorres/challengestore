# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
print(loja.head())
print(loja2.head())
print(loja3.head())
print(loja4.head())
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
# Faturamento total de cada loja
faturamento_loja1 = loja['Preço'].sum()
faturamento_loja2 = loja2['Preço'].sum()
faturamento_loja3 = loja3['Preço'].sum()
faturamento_loja4 = loja4['Preço'].sum()

# %%
print('Faturamento Loja 1:', faturamento_loja1)
print('Faturamento Loja 2:', faturamento_loja2)
print('Faturamento Loja 3:', faturamento_loja3)
print('Faturamento Loja 4:', faturamento_loja4)
# Out:
# Faturamento Loja 1: 1534509.12
# Faturamento Loja 2: 1488459.06
# Faturamento Loja 3: 1464025.03
# Faturamento Loja 4: 1384497.58

# %%
import matplotlib.pyplot as plt
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [1534509.12, 1488459.06, 1464025.03, 1384497.58]

plt.figure(figsize=(8, 8))
plt.pie(faturamentos, labels=lojas, autopct='%1.1f%%', startangle=90, colors=['#4F01BD','#C0108D','#1BBB59','#2064A2'])
plt.title('Particiação de Faturamento por Loja')
plt.axis('equal')  # Grafico de Pizza

plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %% [markdown]
# Calcular quantidade de produtos vendidos por categoria em cada loja

# %%
categorias_loja1 = loja['Categoria do Produto'].value_counts()
categorias_loja2 = loja2['Categoria do Produto'].value_counts()
categorias_loja3 = loja3['Categoria do Produto'].value_counts()
categorias_loja4 = loja4['Categoria do Produto'].value_counts()

print("Categorias mais vendidas - Loja 1:")
print(categorias_loja1)
print("\nCategorias mais vendidas - Loja 2:")
print(categorias_loja2)
print("\nCategorias mais vendidas - Loja 3:")
print(categorias_loja3)
print("\nCategorias mais vendidas - Loja 4:")
print(categorias_loja4)
# Out:
# Categorias mais vendidas - Loja 1:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
#
# Categorias mais vendidas - Loja 2:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
#
# Categorias mais vendidas - Loja 3:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# ...

# %% [markdown]
# Gráfico loja 1:

# %%
import matplotlib.pyplot as plt

categorias_loja1 = loja['Categoria do Produto'].value_counts()
categorias_loja2 = loja2['Categoria do Produto'].value_counts()
categorias_loja3 = loja3['Categoria do Produto'].value_counts()
categorias_loja4 = loja4['Categoria do Produto'].value_counts()

# Exemplo para Loja 1
categorias_loja1.head(6).plot(kind='bar', color='blue')
plt.title('Top 6 Categorias Mais Vendidas - Loja 1')
plt.xlabel('Categoria')
plt.ylabel('Quantidade Vendida')
# Adicionando os valores em cima de cada barra
for i, v in enumerate(categorias_loja1.head(6)):
    plt.text(i, v + 2, str(v), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# Gráfico loja 2:

# %%
import matplotlib.pyplot as plt

# Supondo que 'categorias_loja2' já foi criado com value_counts()
categorias_loja2.plot(kind='bar', color='blue')
plt.title('Categorias Mais Vendidas - Loja 2')
plt.xlabel('Categoria')
plt.ylabel('Quantidade Vendida')

# Adicionando os valores em cima de cada barra
for i, v in enumerate(categorias_loja2):
    plt.text(i, v + 2, str(v), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# Gráfico Loja 3:

# %%
import matplotlib.pyplot as plt

# Supondo que 'categorias_loja3' já foi criado com value_counts()
categorias_loja3.plot(kind='bar', color='blue')
plt.title('Categorias Mais Vendidas - Loja 3')
plt.xlabel('Categoria')
plt.ylabel('Quantidade Vendida')

# Adicionando os valores em cima de cada barra
for i, v in enumerate(categorias_loja3):
    plt.text(i, v + 2, str(v), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# Gráfico Loja 4:

# %%
import matplotlib.pyplot as plt

# Supondo que 'categorias_loja4' já foi criado com value_counts()
categorias_loja4.plot(kind='bar', color='blue')
plt.title('Categorias Mais Vendidas - Loja 4')
plt.xlabel('Categoria')
plt.ylabel('Quantidade Vendida')

# Adicionando os valores em cima de cada barra
for i, v in enumerate(categorias_loja4):
    plt.text(i, v + 2, str(v), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %% [markdown]
# Calcular a média das avaliações dps clientes para cada loja

# %%
# Calculando a média de avaliação das lojas
media_avaliacao_loja1 = loja['Avaliação da compra'].mean()
media_avaliacao_loja2 = loja2['Avaliação da compra'].mean()
media_avaliacao_loja3 = loja3['Avaliação da compra'].mean()
media_avaliacao_loja4 = loja4['Avaliação da compra'].mean()

# Exibindo os resultados
print(f'Média de Avaliação - Loja 1: {media_avaliacao_loja1:.2f}')
print(f'Média de Avaliação - Loja 2: {media_avaliacao_loja2:.2f}')
print(f'Média de Avaliação - Loja 3: {media_avaliacao_loja3:.2f}')
print(f'Média de Avaliação - Loja 4: {media_avaliacao_loja4:.2f}')
# Out:
# Média de Avaliação - Loja 1: 3.98
# Média de Avaliação - Loja 2: 4.04
# Média de Avaliação - Loja 3: 4.05
# Média de Avaliação - Loja 4: 4.00

# %%
import matplotlib.pyplot as plt

# Dados das médias de avaliação
medias_avaliacao = {
    'Loja 1': 3.98,
    'Loja 2': 4.04,
    'Loja 3': 4.05,
    'Loja 4': 4.00
}

plt.figure(figsize=(8,6))
barras = plt.bar(medias_avaliacao.keys(), medias_avaliacao.values(), color='green')
plt.title('Média das Avaliações por Lojas')
plt.xlabel('Loja')
plt.ylabel('Média de Avaliação')

# Adicionando os valores em cima de cada barra
for i, barra in enumerate(barras):
    y = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, y + 0.01, f'{y:.2f}',
             ha='center', va='bottom', fontsize=10)

plt.ylim(3.9, 4.1)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# Produto mais vendido e o produto menos vendido em cada loja:

# %%
# Produto mais vendido e menos vendido na Loja 1
mais_vendido_loja1 = loja['Produto'].value_counts().idxmax()
qtd_mais_vendido_loja1 = loja['Produto'].value_counts().max()
menos_vendido_loja1 = loja['Produto'].value_counts().idxmin()
qtd_menos_vendido_loja1 = loja['Produto'].value_counts().min()

print(f'Loja 1: Mais vendido: {mais_vendido_loja1.title()} ({qtd_mais_vendido_loja1} vendas)')
print(f'Loja 1: Menos vendido: {menos_vendido_loja1.title()} ({qtd_menos_vendido_loja1} venda)')
# Out:
# Loja 1: Mais vendido: Micro-Ondas (60 vendas)
# Loja 1: Menos vendido: Headset (33 venda)

# %%
# Produto mais vendido e menos vendido na Loja 2
mais_vendido_loja2 = loja2['Produto'].value_counts().idxmax()
qtd_mais_vendido_loja2 = loja2['Produto'].value_counts().max()
menos_vendido_loja2 = loja2['Produto'].value_counts().idxmin()
qtd_menos_vendido_loja2 = loja2['Produto'].value_counts().min()

print(f'Loja 2: Mais vendido: {mais_vendido_loja2.title()} ({qtd_mais_vendido_loja2} vendas)')
print(f'Loja 2: Menos vendido: {menos_vendido_loja2.title()} ({qtd_menos_vendido_loja2} venda)')
# Out:
# Loja 2: Mais vendido: Iniciando Em Programação (65 vendas)
# Loja 2: Menos vendido: Jogo De Tabuleiro (32 venda)

# %%
# Produto mais vendido e menos vendido na Loja 3
mais_vendido_loja3 = loja3['Produto'].value_counts().idxmax()
qtd_mais_vendido_loja3 = loja3['Produto'].value_counts().max()
menos_vendido_loja3 = loja3['Produto'].value_counts().idxmin()
qtd_menos_vendido_loja3 = loja3['Produto'].value_counts().min()

print(f'Loja 3: Mais vendido: {mais_vendido_loja3.title()} ({qtd_mais_vendido_loja3} vendas)')
print(f'Loja 3: Menos vendido: {menos_vendido_loja3.title()} ({qtd_menos_vendido_loja3} venda)')
# Out:
# Loja 3: Mais vendido: Kit Banquetas (57 vendas)
# Loja 3: Menos vendido: Blocos De Montar (35 venda)

# %%
# Produto mais vendido e menos vendido na Loja 4
mais_vendido_loja4 = loja4['Produto'].value_counts().idxmax()
qtd_mais_vendido_loja4 = loja4['Produto'].value_counts().max()
menos_vendido_loja4 = loja4['Produto'].value_counts().idxmin()

qtd_menos_vendido_loja4 = loja4['Produto'].value_counts().min()

print(f'Loja 4: Mais vendido: {mais_vendido_loja4.title()} ({qtd_mais_vendido_loja4} vendas)')
print(f'Loja 4: Menos vendido: {menos_vendido_loja4.title()} ({qtd_menos_vendido_loja4} venda)')
# Out:
# Loja 4: Mais vendido: Cama Box (62 vendas)
# Loja 4: Menos vendido: Guitarra (33 venda)

# %%
import matplotlib.pyplot as plt

# Dados dos produtos mais vendidos e suas quantidades
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
produtos = ['Micro-Ondas', 'Iniciando Em Programação', 'Kit Banquetas', 'Cama Box']
vendas = [60, 65, 57, 62]

plt.figure(figsize=(8,6))
barras = plt.bar(lojas, vendas, color='yellow')

plt.title('Produto Mais Vendido por Loja')
plt.xlabel('Loja')
plt.ylabel('Quantidade de Vendas')

# Adicionando os nomes dos produtos e valores em cima de cada barra
for i, barra in enumerate(barras):
    y = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, y + 1, f'{produtos[i]}\n({vendas[i]})',
             ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %%
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
produtos = ['Headset', 'jogo de tabuleiro', 'bloco De Montar', 'Guitarra']
vendas = [33, 32, 35, 33]

plt.figure(figsize=(7,6))
barras = plt.bar(lojas, vendas, color='pink')

plt.title('Produto Menos Vendido por Loja')
plt.xlabel('Loja')
plt.ylabel('Quantidade de Vendas')

# Adicionando os nomes dos produtos e valores em cima de cada barra
for i, barra in enumerate(barras):
    y = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, y + 1, f'{produtos[i]}\n({vendas[i]})',
             ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Frete Médio de cada loja

# %%
import pandas as pd

# URLs dos arquivos CSV
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

# Dados do frete médio das lojas
loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# Calculando o frete médio de cada loja
frete_medio_loja = loja['Frete'].mean()
frete_medio_loja2 = loja2['Frete'].mean()
frete_medio_loja3 = loja3['Frete'].mean()
frete_medio_loja4 = loja4['Frete'].mean()

# Exibindo os resultados
print(f'Frete médio - Loja 1: R$ {frete_medio_loja:.2f}')
print(f'Frete médio - Loja 2: R$ {frete_medio_loja2:.2f}')
print(f'Frete médio - Loja 3: R$ {frete_medio_loja3:.2f}')
print(f'Frete médio - Loja 4: R$ {frete_medio_loja4:.2f}')
# Out:
# Frete médio - Loja 1: R$ 34.69
# Frete médio - Loja 2: R$ 33.62
# Frete médio - Loja 3: R$ 33.07
# Frete médio - Loja 4: R$ 31.28

# %%
import matplotlib.pyplot as plt

# Dados do frete médio das lojas
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
fretes = [34.69, 33.62, 33.07, 31.28]

plt.figure(figsize=(8,4))
barra = plt.bar(lojas, fretes, color='blue')
plt.title('Frete Médio por Loja')
plt.xlabel('Loja')
plt.ylabel('Frete Médio (R$)')

# Adicionando os valores em cima de cada barra
for i, barra in enumerate(barra):
    y = barra.get_height()
    plt.text(barra.get_x() + barra.get_width()/2, y + 0.2, f'R$ {y:.2f}',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados do frete médio das lojas
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
fretes = [34.69, 33.62, 33.07, 31.28]

plt.figure(figsize=(8, 4))
plt.plot(lojas, fretes, marker='o', linestyle='-', color='blue', linewidth=2)

plt.title('Frete Médio por Loja')
plt.xlabel('Loja')
plt.ylabel('Frete Médio (R$)')

# Adicionando os valores acima dos pontos
for i, valor in enumerate(fretes):
    plt.text(i, valor + 0.2, f'R$ {valor:.2f}',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # **6.**Relatorio Final

# %% [markdown]
# A Loja 4 demonstrou, ao longo da análise, o desempenho mais fraco da rede. Seu faturamento é significativamente inferior às demais unidades, revelando baixa eficiência comercial. Embora suas avaliações estejam próximas da média geral, a percepção do cliente é apenas mediana, sem diferenciais que indiquem fidelização ou excelência no atendimento.
#
# Os produtos mais vendidos da loja não se destacam em volume, e o mix de categorias segue um padrão semelhante ao das outras unidades, sem apresentar foco estratégico ou especialização que agregue valor. Apesar de oferecer o menor frete médio da rede, esse diferencial não tem se traduzido em ganho competitivo ou aumento nas vendas.
#
# Diante desses fatores, recomenda-se a descontinuidade da operação da Loja 4. A venda da unidade permitiria ao Sr. João liberar capital para reinvestimento em oportunidades mais promissoras, aumentando o retorno sobre o investimento e fortalecendo a performance global do e-commerce.
